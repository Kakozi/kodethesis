# %%
import pandas as pd

input_file = "AnonDB_zub.csv"
output_file = "AnonDB_zub_60.csv"

df = pd.read_csv(input_file, delimiter=";")

if "Num_Cells" not in df.columns:
    raise ValueError("Kolom 'Num_Cells' tidak ditemukan di file CSV.")

# Ubah Num_Cells menjadi angka
df["Num_Cells"] = pd.to_numeric(df["Num_Cells"], errors="coerce")

# Filter 60 cells
df_60 = df[df["Num_Cells"] == 60].copy()

# Simpan hasil
df_60.to_csv(output_file, index=False)

print(f"File berhasil dibuat: {output_file}")
print(f"Jumlah data awal: {len(df)}")
print(f"Jumlah data dengan Num_Cells = 60: {len(df_60)}")
print(f"Jumlah data dibuang: {len(df) - len(df_60)}")
# Out:
# File berhasil dibuat: AnonDB_zub_60.csv
# Jumlah data awal: 621
# Jumlah data dengan Num_Cells = 60: 437
# Jumlah data dibuang: 184

# %%
import pandas as pd

input_file = "AnonDB_sdm_sandia.csv"
output_file = "AnonDB_sandia_60.csv"

# Baca semua kolom sebagai string dulu supaya kode indeks tidak berubah jadi float
df = pd.read_csv(input_file, delimiter=";", dtype=str)

# Hapus kolom Unnamed kalau memang hanya kolom index kosong dari CSV sebelumnya
unnamed_cols = [col for col in df.columns if col.startswith("Unnamed")]

print("Kolom Unnamed yang ditemukan:")
print(unnamed_cols)

# Kalau kolom Unnamed itu tidak diperlukan, hapus
df = df.drop(columns=unnamed_cols)

# Pastikan kolom Num_Cells ada
if "Num_Cells" not in df.columns:
    raise ValueError("Kolom 'Num_Cells' tidak ditemukan di file CSV.")

# Bersihkan Num_Cells lalu ubah ke numeric hanya untuk filtering
num_cells_numeric = pd.to_numeric(df["Num_Cells"], errors="coerce")

# Filter hanya Num_Cells = 60
df_60 = df[num_cells_numeric == 60].copy()

# Simpan hasil
df_60.to_csv(output_file, index=False)

print(f"File berhasil dibuat: {output_file}")
print(f"Jumlah data awal: {len(df)}")
print(f"Jumlah data dengan Num_Cells = 60: {len(df_60)}")
print(f"Jumlah data dibuang: {len(df) - len(df_60)}")
# Out:
# Kolom Unnamed yang ditemukan:
# ['Unnamed: 0']
# File berhasil dibuat: AnonDB_zub_60.csv
# Jumlah data awal: 621
# Jumlah data dengan Num_Cells = 60: 437
# Jumlah data dibuang: 184

# %%
df
# Out:
#      Unnamed: 0  Mod_ID  Confidential  Make  Model  Interconnect_Tech  \
# 0         609.0  3360.0           NaN  36.0    4.0                NaN
# 1         608.0  3359.0           NaN  36.0    4.0                NaN
# 2         613.0  3375.0           NaN  36.0    5.0                NaN
# 3         610.0  3371.0           NaN  36.0    7.0                NaN
# 4         611.0  3373.0           NaN  36.0    7.0                NaN
# ..          ...     ...           ...   ...    ...                ...
# 616         NaN     NaN           NaN   NaN    NaN                NaN
# 617         NaN     NaN           NaN   NaN    NaN                NaN
# 618         NaN     NaN           NaN   NaN    NaN                NaN
# 619         NaN     NaN           NaN   NaN    NaN                NaN
# 620         NaN     NaN           NaN   NaN    NaN                NaN
#
#      Module_Area_(cm2)  Junction_Box_Type  Cell_Wafer_Type  Cell_Tech  ...  \
# 0              21620.8                NaN  multi-Si module        NaN  ...
# 1              21620.8                NaN  multi-Si module        NaN  ...
# 2              21620.8                NaN  multi-Si module        NaN  ...
# 3              21620.8                NaN  multi-Si module        NaN  ...
# 4              21620.8                NaN  multi-Si module        NaN  ...
# ..                 ...                ...              ...        ...  ...
# 616                NaN                NaN              NaN        NaN  ...
# 617                NaN                NaN              NaN        NaN  ...
# 618                NaN                NaN              NaN        NaN  ...
# 619                NaN                NaN              NaN        NaN  ...
# 620                NaN                NaN              NaN        NaN  ...
#
#                              ELLPath                       IVPath  Ref  \
# 0    ./EL/3360_36_4_03162016_20.tiff  ./IV/3360_36_4_03162016.csv  0.0
# 1    ./EL/3359_36_4_03162016_20.tiff  ./IV/3359_36_4_03162016.csv  0.0
# 2    ./EL/3375_36_5_03162016_20.tiff  ./IV/3375_36_5_03162016.csv  0.0
# 3    ./EL/3371_36_7_03182016_20.tiff  ./IV/3371_36_7_03162016.csv  0.0
# 4    ./EL/3373_36_7_03162016_20.tiff  ./IV/3373_36_7_03162016.csv  0.0
# ..                               ...                          ...  ...
# 616                              NaN                          NaN  NaN
# 617                              NaN                          NaN  NaN
# 618                              NaN                          NaN  NaN
# 619                              NaN                          NaN  NaN
# 620                              NaN                          NaN  NaN
#
#      Exposure_Step  Total_Exposure_Steps                       RefIVPath  \
# 0              0.0              1.000000  ./RefIV/3360_36_4_03162016.csv
# 1              0.0              1.000000  ./RefIV/3359_36_4_03162016.csv
# 2              0.0              1.000000  ./RefIV/3375_36_5_03162016.csv
# 3              0.0              1.000000  ./RefIV/3371_36_7_03162016.csv
# 4              0.0              1.000000  ./RefIV/3373_36_7_03162016.csv
# ..             ...                   ...                             ...
# 616            NaN                   NaN                             NaN
# 617            NaN              1.610390                             NaN
# 618            NaN              0.576168                             NaN
# 619            NaN              1.000000                             NaN
# 620            NaN              3.000000                             NaN
#
#      RefA  RefRefA  Ref_IV_Date  Ref_IV_Time
# 0     NaN      NaN    3/16/2016     09:07:56
# 1     NaN      NaN    3/16/2016     08:30:38
# 2     NaN      NaN    3/16/2016     16:06:34
# 3     NaN      NaN    3/16/2016     13:00:08
# 4     NaN      NaN    3/16/2016     14:32:16
# ..    ...      ...          ...          ...
# 616   NaN      NaN          NaN          NaN
# 617   NaN      NaN          NaN          NaN
# 618   NaN      NaN          NaN          NaN
# 619   NaN      NaN          NaN          NaN
# 620   NaN      NaN          NaN          NaN
#
# [621 rows x 67 columns]

# %%
import pandas as pd
from pathlib import Path

input_file = "AnonDB_Zub_96.csv"
output_file = "AnonDB_Zub_96.csv"

df = pd.read_csv(input_file, delimiter=",")

df["module_code"] = (
    df["ELHPath"]
    .astype(str)
    .apply(lambda x: Path(x).stem)          # ambil nama file tanpa .tiff
    .str.replace(r"_(20|80)$", "", regex=True)  # hapus suffix _80 atau _20
)

df.to_csv(output_file, index=False)

print(f"Saved to {output_file}")
print(df[["ELHPath", "module_code"]].head())

#df.to_csv("AnonDB_Zub_72_96.csv", index=False)
# Out:
# Saved to AnonDB_Zub_96.csv
#                            ELHPath         module_code
# 0  ./EL/4194_22_4_09142018_80.tiff  4194_22_4_09142018
# 1  ./EL/4185_22_4_09142018_80.tiff  4185_22_4_09142018
# 2  ./EL/4187_22_4_09142018_80.tiff  4187_22_4_09142018
# 3  ./EL/4190_22_4_09142018_80.tiff  4190_22_4_09142018
# 4  ./EL/4193_22_4_09142018_80.tiff  4193_22_4_09142018

# %%
import pandas as pd

df1 = pd.read_csv("module_summary.csv")
df2 = pd.read_csv("AnonDB_sandia_60.csv")

df1["module"] = df1["module"].astype(str).str.strip()
df2["module_code"] = df2["module_code"].astype(str).str.strip()

merged = pd.merge(
    df1,
    df2,
    left_on="module",
    right_on="module_code",
    how="inner"
)

merged = merged.drop(columns=["module_code"])

merged.to_csv("merged_sdm.csv", index=False)
