# %%
import os
import glob
import cv2
import numpy as np

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # I0 ESTIMATION => Rajput 2018

# %% [markdown]
# Quantitative estimation of electrical performance parameters of individual solar cells in silicon photovoltaic modules using electroluminescence imaging

# %%
def load_image_and_remove_padding(
        image_path,
        min_valid_intensity=2,
        return_mask=False):
    """
    Load grayscale EL image and remove padding/bezel pixels.

    Parameters
    ----------
    image_path : str
        Path ke file .tiff
    min_valid_intensity : int
        Threshold untuk buang padding (default 2)
    return_mask : bool
        Kalau True, return juga mask 2D untuk visualisasi

    Returns
    -------
    phi_values : 1D numpy array
        Pixel intensity valid (tanpa padding)
    mask (optional) : 2D boolean array
    """

    # Load image grayscale
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    if img is None:
        raise ValueError(f"Gagal load image: {image_path}")

    img = img.astype(np.float64)

    # Mask padding
    mask = img >= min_valid_intensity

    intensity_map = img[mask]

    if intensity_map.size == 0:
        raise ValueError("Tidak ada pixel valid setelah padding removal.")

    if return_mask:
        return intensity_map, mask
    else:
        return intensity_map

# %%
def trim_outliers(values, lower_percentile=0.1, upper_percentile=99.9):
    """
    Remove extreme outliers from a 1D array using percentile thresholds.

    Parameters
    ----------
    values : array-like
        Input data (misalnya intensity pixel).
    lower_percentile : float
        Persentil bawah yang dipertahankan.
    upper_percentile : float
        Persentil atas yang dipertahankan.

    Returns
    -------
    trimmed_values : numpy array
        Array tanpa outlier.
    """

    v = np.asarray(values, dtype=np.float64)

    # buang NaN
    v = v[np.isfinite(v)]

    if v.size == 0:
        return v

    lo = np.percentile(v, lower_percentile)
    hi = np.percentile(v, upper_percentile)

    trimmed = v[(v >= lo) & (v <= hi)]

    return trimmed

# %%
def compute_f(intensity_map,
              I,
              Uth=0.0259,
              VT=0.0,
              N=1,
              pixel_area=1.0,
              min_valid_intensity=2):
    """
    Menghitung nilai f berdasarkan persamaan:
    
    f = exp( ( Σ_i (Uth/2 * ln( I / ∫(1/phi) d^2r )) - VT ) / (30*Uth) )
    
    Parameters
    ----------
    phi_image : 2D numpy array
        EL intensity image
    I : float
        Injected current (Ampere)
    Uth : float
        Thermal voltage (kT/q)
    VT : float
        Tegangan offset (Volt)
    N : int
        Jumlah cell (kalau memang ingin dikalikan N)
    pixel_area : float
        Luas tiap pixel (default 1 untuk relatif)
    min_valid_intensity : int
        Untuk buang padding/bezel
    
    Returns
    -------
    f : float
    """

    phi = intensity_map.astype(np.float64)

    # Buang padding (nilai 0-1)
    mask = phi >= min_valid_intensity
    phi_valid = phi[mask]

    if phi_valid.size == 0:
        raise ValueError("Tidak ada pixel valid setelah masking.")

    # Diskretisasi integral ∫ (1/phi) d^2r
    integral_inv_phi = np.sum((1.0 / phi_valid) * pixel_area)

    if integral_inv_phi <= 0:
        raise ValueError("Integral tidak valid.")

    # Term dalam log
    log_term = np.log(I / integral_inv_phi)

    # Σ_i (...)  → kalau semua cell identik tinggal N dikali
    sum_term = N * (Uth / 2.0) * log_term

    # Final expression
    exponent = (sum_term - VT) / (30.0 * Uth)

    f = np.exp(exponent)

    return float(f)

# %%
import numpy as np

def compute_Vi_from_phi_values(intensity_map,
                               I,
                               f,
                               Uth=0.0259,
                               pixel_area=1.0):
    """
    Compute terminal voltage:
        Vi = (Uth/2) * ln( I / ( f * ∫(1/phi) d^2r ) )

    Parameters
    ----------
    phi_values : 1D numpy array
        Cleaned intensity values (padding removed already).
    I : float
        Injected current (Ampere).
    f : float
        Calibration factor.
    Uth : float
        Thermal voltage (kT/q or effective).
    pixel_area : float
        Area per pixel (set 1.0 if you only need relative scale).

    Returns
    -------
    Vi : float
        Terminal voltage (Volt).
    """
    phi = np.asarray(intensity_map, dtype=np.float64)

    if phi.size == 0:
        raise ValueError("phi_values kosong.")
    if np.any(phi <= 0):
        raise ValueError("phi_values mengandung nilai <= 0 (tidak boleh untuk 1/phi dan log).")
    if f <= 0 or I <= 0:
        raise ValueError("I dan f harus > 0.")

    integral_inv_phi = np.sum((1.0 / phi) * float(pixel_area))
    if integral_inv_phi <= 0:
        raise ValueError("Integral ∑(1/phi)*dA tidak valid.")

    arg = I / (f * integral_inv_phi)
    if arg <= 0:
        raise ValueError("Argumen log tidak valid (<=0).")

    Vi = (Uth / 2.0) * np.log(arg)
    return float(Vi)

# %%
import numpy as np

def compute_c_map(phi_image, Vi, Uth=0.0259, min_valid_intensity=2):
    """
    Compute c(r) map in 2D.

    c(r) = Phi(r) * exp( -Vi / Uth )
    (Low bias assumption: U(r) ≈ Vi)

    Returns:
        c_map (2D numpy array)
        mask   (valid pixel mask)
    """
    phi = phi_image.astype(np.float64)

    mask = phi >= min_valid_intensity

    c_map = np.full_like(phi, np.nan, dtype=np.float64)

    scale = np.exp(-float(Vi) / float(Uth))

    c_map[mask] = phi[mask] * scale

    return c_map, mask


def compute_J0_map(c_map, f):
    """
    Compute J0(r) map in 2D:

    J0(r) = f / c(r)

    Returns:
        J0_map (2D numpy array)
    """
    if f <= 0:
        raise ValueError("f harus > 0.")

    J0_map = np.full_like(c_map, np.nan, dtype=np.float64)

    valid = np.isfinite(c_map) & (c_map > 0)

    J0_map[valid] = float(f) / c_map[valid]

    return J0_map

# %% [markdown]
# # Rs Estimation => Rajput 2018

# %%
import cv2
import numpy as np

def load_gray_cv2(path: str) -> np.ndarray:
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Gagal load image: {path}")
    return img.astype(np.float64)

def make_valid_mask(phi: np.ndarray, min_valid_intensity: int = 2) -> np.ndarray:
    # buang padding/bezel 0-1
    return (phi >= float(min_valid_intensity)) & np.isfinite(phi)

def compute_U_map(phi: np.ndarray, c_map: np.ndarray, Uth: float, mask: np.ndarray) -> np.ndarray:
    """
    U(r) = Uth * ln( Phi(r) / c(r) )
    """
    if phi.shape != c_map.shape:
        raise ValueError("phi dan c_map harus punya shape yang sama.")
    U = np.full_like(phi, np.nan, dtype=np.float64)

    safe = mask & np.isfinite(c_map) & (c_map > 0) & (phi > 0)
    U[safe] = Uth * np.log(phi[safe] / c_map[safe])
    return U

def estimate_Vi_from_brightest(phi: np.ndarray, U_map: np.ndarray, mask: np.ndarray,
                               exclude_top_percent: float = 0.1,
                               band_width_percent: float = 0.4) -> float:
    """
    Vi diambil dari area paling terang (brightest spot), exclude top 0.1% intensitas
    untuk menghindari outlier/saturasi. Vi = median(U) di band intensitas near-brightest.
    """
    safe = mask & np.isfinite(U_map) & np.isfinite(phi)
    vals = phi[safe]
    if vals.size < 50:
        raise ValueError("Terlalu sedikit pixel valid untuk estimasi Vi.")

    p_hi = 100.0 - exclude_top_percent       # contoh 99.9
    p_lo = max(p_hi - band_width_percent, 0) # contoh 99.5

    thr_hi = np.percentile(vals, p_hi)
    thr_lo = np.percentile(vals, p_lo)

    band = safe & (phi >= thr_lo) & (phi <= thr_hi)
    U_band = U_map[band]

    if U_band.size == 0:
        # fallback: ambil U maksimum di bawah thr_hi
        cand = safe & (phi <= thr_hi)
        return float(np.nanmax(U_map[cand]))

    return float(np.nanmedian(U_band))

def compute_J_map(J0_map: np.ndarray, U_map: np.ndarray, Uth: float, mask: np.ndarray) -> np.ndarray:
    """
    J(r) = J0(r) * exp(U/Uth)
    """
    if J0_map.shape != U_map.shape:
        raise ValueError("J0_map dan U_map harus punya shape yang sama.")
    J = np.full_like(U_map, np.nan, dtype=np.float64)
    safe = mask & np.isfinite(J0_map) & (J0_map > 0) & np.isfinite(U_map)
    J[safe] = J0_map[safe] * np.exp(U_map[safe] / Uth)
    return J

def compute_Rs_map(Vi: float, U_map: np.ndarray, J_map: np.ndarray, mask: np.ndarray,
                   min_abs_J: float = 1e-30) -> np.ndarray:
    """
    Rs(r) = (Vi - U(r)) / J(r)
    min_abs_J mencegah division blow-up di area J sangat kecil.
    """
    Rs = np.full_like(U_map, np.nan, dtype=np.float64)
    safe = mask & np.isfinite(U_map) & np.isfinite(J_map) & (np.abs(J_map) > min_abs_J)
    Rs[safe] = (float(Vi) - U_map[safe]) / J_map[safe]
    return Rs

def estimate_U_J_Rs_maps_from_highbias(
    phi_high_path: str,
    c_map: np.ndarray,
    J0_map: np.ndarray,
    Uth: float = 0.0259,
    min_valid_intensity: int = 2,
    exclude_top_percent: float = 0.1,
    band_width_percent: float = 0.4
):
    """
    High-bias pipeline:
    1) Load phi_high
    2) U_map = Uth ln(phi/c)
    3) Vi = median U pada brightest region (exclude top 0.1% phi)
    4) J_map = J0 exp(U/Uth)
    5) Rs_map = (Vi - U) / J
    """
    phi = load_gray_cv2(phi_high_path)
    mask = make_valid_mask(phi, min_valid_intensity=min_valid_intensity)

    U_map = compute_U_map(phi, c_map=c_map, Uth=Uth, mask=mask)
    Vi = estimate_Vi_from_brightest(phi, U_map=U_map, mask=mask,
                                    exclude_top_percent=exclude_top_percent,
                                    band_width_percent=band_width_percent)
    J_map = compute_J_map(J0_map=J0_map, U_map=U_map, Uth=Uth, mask=mask)
    Rs_map = compute_Rs_map(Vi=Vi, U_map=U_map, J_map=J_map, mask=mask)

    return {
        "phi_high": phi,
        "mask": mask,
        "Vi": Vi,
        "U_map": U_map,
        "J_map": J_map,
        "Rs_map": Rs_map
    }

# %% [markdown]
# # Try Rs Mapping in Module

# %%
# ----------------------------
# INPUT (ganti sesuai foldermu)
# ----------------------------
low_module_path  = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL\EL_wrp\2529_36_1_08062019_20_wrp.tiff"
high_module_path = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL\EL_wrp\2529_36_1_08062019_80_wrp.tiff"

I_low = 0.2*5.908          # A (arus injeksi low)
Uth  = 0.0259
VT   = 0.0
N    = 60            # sesuai modul kamu

# ----------------------------
# 1) LOW-BIAS: f, Vi_low, c_map, J0_map
# ----------------------------
phi_low_values = load_image_and_remove_padding(low_module_path, min_valid_intensity=2)
phi_low_values = trim_outliers(phi_low_values, lower_percentile=0.1, upper_percentile=99.9)

f = compute_f(phi_low_values, I=I_low, Uth=Uth, VT=VT, N=N)
Vi_low = compute_Vi_from_phi_values(phi_low_values, I=I_low, f=f, Uth=Uth)

phi_low_img = load_gray_cv2(low_module_path)
c_map, mask_low = compute_c_map(phi_low_img, Vi=Vi_low, Uth=Uth, min_valid_intensity=2)
J0_map = compute_J0_map(c_map, f=f)

print("LOW done: f=", f, "| Vi_low=", Vi_low)

# ----------------------------
# 2) HIGH-BIAS: U_map, Vi_high (brightest), J_map, Rs_map
# ----------------------------
phi_high_img = load_gray_cv2(high_module_path)
mask_high = make_valid_mask(phi_high_img, min_valid_intensity=2)
mask = mask_low & mask_high

U_map = compute_U_map(phi_high_img, c_map=c_map, Uth=Uth, mask=mask)

Vi_high = estimate_Vi_from_brightest(
    phi_high_img, U_map=U_map, mask=mask,
    exclude_top_percent=0.1, band_width_percent=0.4
)

J_map = compute_J_map(J0_map=J0_map, U_map=U_map, Uth=Uth, mask=mask)
Rs_map = compute_Rs_map(Vi=Vi_high, U_map=U_map, J_map=J_map, mask=mask)

print("HIGH done: Vi_high=", Vi_high)
print("Rs median=", np.nanmedian(Rs_map), "| Rs mean=", np.nanmean(Rs_map))

# ----------------------------
# 3) VISUALISASI
# ----------------------------
# Supaya enak dilihat, pakai percentile clipping (visual saja)
def clip_for_display(img, mask, p_low=2, p_high=98):
    vals = img[mask & np.isfinite(img)]
    if vals.size == 0:
        return img
    lo, hi = np.percentile(vals, [p_low, p_high])
    return np.clip(img, lo, hi)

phi_disp = clip_for_display(phi_high_img, mask, 2, 98)
U_disp   = clip_for_display(U_map, mask, 2, 98)
J_disp   = clip_for_display(J_map, mask, 2, 98)
Rs_disp  = clip_for_display(Rs_map, mask, 2, 98)
phi_low_disp = clip_for_display(phi_low_img, mask, 2, 98)

plt.figure(figsize=(14, 10))

plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
plt.imshow(phi_low_disp, cmap="gray")
plt.title("Low-bias intensity (clipped)")
plt.colorbar()

plt.subplot(2, 2, 2)
plt.imshow(phi_disp, cmap="gray")
plt.title("High-bias intensity (clipped)")
plt.colorbar()

plt.subplot(2, 2, 3)
plt.imshow(J_disp, cmap="magma")
plt.title("J(r) map (clipped)")
plt.colorbar()

plt.subplot(2, 2, 4)
plt.imshow(Rs_disp, cmap="inferno")
plt.title("Rs(r) map (clipped)")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# LOW done: f= 4.8464746012544095e-06 | Vi_low= -4.3132164506687334e-18
# HIGH done: Vi_high= 0.005028640774020791
# Rs median= 1561.5586959749694 | Rs mean= 13044.754032300827

# %% [markdown]
# # Mapping the Rs in Module

# %%
import os
import numpy as np
import matplotlib.pyplot as plt


def clip_for_display(img, mask, p_low=2, p_high=98):
    vals = img[mask & np.isfinite(img)]
    if vals.size == 0:
        return img
    lo, hi = np.percentile(vals, [p_low, p_high])
    return np.clip(img, lo, hi)


def summarize_map(name, arr, mask):
    vals = arr[mask & np.isfinite(arr)]
    if vals.size == 0:
        print(f"{name:12s}: tidak ada nilai valid")
        return {
            "mean": np.nan,
            "median": np.nan,
            "min": np.nan,
            "max": np.nan,
            "n": 0
        }

    summary = {
        "mean": float(np.mean(vals)),
        "median": float(np.median(vals)),
        "min": float(np.min(vals)),
        "max": float(np.max(vals)),
        "n": int(vals.size)
    }

    print(
        f"{name:12s}: "
        f"mean = {summary['mean']:.6f}, "
        f"median = {summary['median']:.6f}, "
        f"min = {summary['min']:.6f}, "
        f"max = {summary['max']:.6f}, "
        f"n = {summary['n']}"
    )
    return summary


def run_single_cell_analysis(
    low_cell_path,
    high_cell_path,
    I_low,
    Uth=0.0259,
    VT=0.0,
    N=1,
    min_valid_intensity=2
):
    # ----------------------------
    # LOW-BIAS
    # ----------------------------
    phi_low_values = load_image_and_remove_padding(
        low_cell_path,
        min_valid_intensity=min_valid_intensity
    )
    phi_low_values = trim_outliers(
        phi_low_values,
        lower_percentile=0.1,
        upper_percentile=99.9
    )

    f = compute_f(phi_low_values, I=I_low, Uth=Uth, VT=VT, N=N)
    Vi_low = compute_Vi_from_phi_values(phi_low_values, I=I_low, f=f, Uth=Uth)

    phi_low_img = load_gray_cv2(low_cell_path)
    c_map, mask_low = compute_c_map(
        phi_low_img,
        Vi=Vi_low,
        Uth=Uth,
        min_valid_intensity=min_valid_intensity
    )
    J0_map = compute_J0_map(c_map, f=f)

    # ----------------------------
    # HIGH-BIAS
    # ----------------------------
    phi_high_img = load_gray_cv2(high_cell_path)
    mask_high = make_valid_mask(phi_high_img, min_valid_intensity=min_valid_intensity)
    mask = mask_low & mask_high

    U_map = compute_U_map(
        phi_high_img,
        c_map=c_map,
        Uth=Uth,
        mask=mask
    )

    Vi_high = estimate_Vi_from_brightest(
        phi_high_img,
        U_map=U_map,
        mask=mask,
        exclude_top_percent=0.1,
        band_width_percent=0.4
    )

    J_map = compute_J_map(
        J0_map=J0_map,
        U_map=U_map,
        Uth=Uth,
        mask=mask
    )

    Rs_map = compute_Rs_map(
        Vi=Vi_high,
        U_map=U_map,
        J_map=J_map,
        mask=mask
    )

    # ----------------------------
    # SUMMARY
    # ----------------------------
    print("=" * 90)
    print("SINGLE CELL ANALYSIS")
    print("-" * 90)
    print("Low cell file  :", os.path.basename(low_cell_path))
    print("High cell file :", os.path.basename(high_cell_path))
    print(f"I_low          : {I_low}")
    print(f"Uth            : {Uth}")
    print(f"VT             : {VT}")
    print(f"N              : {N}")
    print(f"f              : {f}")
    print(f"Vi_low         : {Vi_low}")
    print(f"Vi_high        : {Vi_high}")
    print("=" * 90)

    summaries = {}

    # intensity summaries
    low_vals_valid = phi_low_img[mask & np.isfinite(phi_low_img)]
    high_vals_valid = phi_high_img[mask & np.isfinite(phi_high_img)]

    print("\nINTENSITY SUMMARY")
    print("-" * 90)

    if low_vals_valid.size > 0:
        print(
            f"{'Low intensity':12s}: "
            f"mean = {np.mean(low_vals_valid):.6f}, "
            f"median = {np.median(low_vals_valid):.6f}, "
            f"min = {np.min(low_vals_valid):.6f}, "
            f"max = {np.max(low_vals_valid):.6f}, "
            f"n = {low_vals_valid.size}"
        )
        summaries["low_intensity_mean"] = float(np.mean(low_vals_valid))
    else:
        print("Low intensity: tidak ada nilai valid")
        summaries["low_intensity_mean"] = np.nan

    if high_vals_valid.size > 0:
        print(
            f"{'High intensity':12s}: "
            f"mean = {np.mean(high_vals_valid):.6f}, "
            f"median = {np.median(high_vals_valid):.6f}, "
            f"min = {np.min(high_vals_valid):.6f}, "
            f"max = {np.max(high_vals_valid):.6f}, "
            f"n = {high_vals_valid.size}"
        )
        summaries["high_intensity_mean"] = float(np.mean(high_vals_valid))
    else:
        print("High intensity: tidak ada nilai valid")
        summaries["high_intensity_mean"] = np.nan

    print("\nMAP SUMMARY")
    print("-" * 90)
    summaries["c_map"] = summarize_map("c_map", c_map, mask)
    summaries["J0_map"] = summarize_map("J0_map", J0_map, mask)
    summaries["U_map"] = summarize_map("U_map", U_map, mask)
    summaries["J_map"] = summarize_map("J_map", J_map, mask)
    summaries["Rs_map"] = summarize_map("Rs_map", Rs_map, mask)

    # ----------------------------
    # DISPLAY IMAGES
    # ----------------------------
    phi_low_disp = clip_for_display(phi_low_img, mask, 2, 98)
    phi_high_disp = clip_for_display(phi_high_img, mask, 2, 98)
    c_disp = clip_for_display(c_map, mask, 2, 98)
    J0_disp = clip_for_display(J0_map, mask, 2, 98)
    U_disp = clip_for_display(U_map, mask, 2, 98)
    J_disp = clip_for_display(J_map, mask, 2, 98)
    Rs_disp = clip_for_display(Rs_map, mask, 2, 98)

    mask_disp = np.where(mask, 1.0, 0.0)

    plt.figure(figsize=(16, 12))

    plt.subplot(2, 4, 1)
    plt.imshow(phi_low_disp, cmap="gray")
    plt.title("Low intensity")
    plt.colorbar()

    plt.subplot(2, 4, 2)
    plt.imshow(phi_high_disp, cmap="gray")
    plt.title("High intensity")
    plt.colorbar()

    plt.subplot(2, 4, 3)
    plt.imshow(mask_disp, cmap="gray")
    plt.title("Valid mask")
    plt.colorbar()

    plt.subplot(2, 4, 4)
    plt.imshow(c_disp, cmap="viridis")
    plt.title("c_map")
    plt.colorbar()

    plt.subplot(2, 4, 5)
    plt.imshow(J0_disp, cmap="plasma")
    plt.title("J0_map")
    plt.colorbar()

    plt.subplot(2, 4, 6)
    plt.imshow(U_disp, cmap="magma")
    plt.title("U_map")
    plt.colorbar()

    plt.subplot(2, 4, 7)
    plt.imshow(J_disp, cmap="inferno")
    plt.title("J_map")
    plt.colorbar()

    plt.subplot(2, 4, 8)
    plt.imshow(Rs_disp, cmap="cividis")
    plt.title("Rs_map")
    plt.colorbar()

    plt.tight_layout()
    plt.show()

    return {
        "f": f,
        "Vi_low": Vi_low,
        "Vi_high": Vi_high,
        "mask": mask,
        "phi_low_img": phi_low_img,
        "phi_high_img": phi_high_img,
        "c_map": c_map,
        "J0_map": J0_map,
        "U_map": U_map,
        "J_map": J_map,
        "Rs_map": Rs_map,
        "summaries": summaries
    }


# =========================================================
# CONTOH PAKAI
# =========================================================
low_cell_path  = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_20_wrp\3922_20_1_01232020_20_wrp_000.tiff"
high_cell_path = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_80_wrp\3922_20_1_01232020_80_wrp_000.tiff"

I_low = 0.2 * 9.608
Uth = 0.0259
VT = 0.0
N = 1   # coba mulai dari 1 kalau memang image-nya satu cell

out = run_single_cell_analysis(
    low_cell_path=low_cell_path,
    high_cell_path=high_cell_path,
    I_low=I_low,
    Uth=Uth,
    VT=VT,
    N=N,
    min_valid_intensity=2
)
# Out:
# ==========================================================================================
# SINGLE CELL ANALYSIS
# ------------------------------------------------------------------------------------------
# Low cell file  : 3922_20_1_01232020_20_wrp_000.tiff
# High cell file : 3922_20_1_01232020_80_wrp_000.tiff
# I_low          : 1.9216000000000002
# Uth            : 0.0259
# VT             : 0.0
# N              : 1
# f              : 0.8820187190658275
# Vi_low         : -0.09592036492420443
# Vi_high        : -0.0774649245240029
# ==========================================================================================
#
# INTENSITY SUMMARY
# ------------------------------------------------------------------------------------------
# Low intensity: mean = 88.631442, median = 93.000000, min = 2.000000, max = 154.000000, n = 282444
# High intensity: mean = 154.342843, median = 159.000000, min = 2.000000, max = 224.000000, n = 282444
#
# MAP SUMMARY
# ------------------------------------------------------------------------------------------
# c_map       : mean = 3597.432457, median = 3774.746422, min = 81.177342, max = 6250.655365, n = 282444
# J0_map      : mean = 0.000285, median = 0.000234, min = 0.000141, max = 0.010865, n = 282444
# U_map       : mean = -0.081542, median = -0.081795, min = -0.106422, max = -0.042063, n = 282444
# J_map       : mean = 0.000013, median = 0.000010, min = 0.000004, max = 0.002142, n = 282444
# Rs_map      : mean = 411.668424, median = 423.868475, min = -235.136164, max = 4015.669759, n = 282444

# %% [markdown]
# # Run per cell OLD

# %%
import os
import glob
import re
import numpy as np
import pandas as pd
from scipy import stats

low_folder  = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\10084_35_1_01272020_20"
high_folder = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\10084_35_1_01272020_80"

low_files = glob.glob(os.path.join(low_folder,"*.tif*"))
high_files = glob.glob(os.path.join(high_folder,"*.tif*"))

# -----------------------------
# index high files by cell id
# -----------------------------
high_dict = {}

for f in high_files:
    name = os.path.basename(f)
    cell_id = re.search(r'cell_\d+', name).group()
    high_dict[cell_id] = f


results = []

for low_path in low_files:

    name = os.path.basename(low_path)

    cell_id = re.search(r'cell_\d+', name).group()

    if cell_id not in high_dict:
        print("missing pair:", cell_id)
        continue

    high_path = high_dict[cell_id]

    print("processing", cell_id)

    # ---------------------
    # LOW BIAS
    # ---------------------
    phi_low_img = load_gray_cv2(low_path)

    phi_low_values = load_image_and_remove_padding(low_path)
    phi_low_values = trim_outliers(phi_low_values,0.1,99.9)

    f = compute_f(phi_low_values,I=I_low,Uth=Uth,VT=VT,N=N)

    Vi_low = compute_Vi_from_phi_values(
        phi_low_values,
        I=I_low,
        f=f,
        Uth=Uth
    )

    c_map, mask_low = compute_c_map(phi_low_img,Vi_low,Uth=Uth)

    J0_map = compute_J0_map(c_map,f)


    # ---------------------
    # HIGH BIAS
    # ---------------------
    phi_high_img = load_gray_cv2(high_path)

    mask_high = make_valid_mask(phi_high_img)

    mask = mask_low & mask_high

    U_map = compute_U_map(
        phi_high_img,
        c_map=c_map,
        Uth=Uth,
        mask=mask
    )

    Vi_high = estimate_Vi_from_brightest(
        phi_high_img,
        U_map=U_map,
        mask=mask,
        exclude_top_percent=0.1
    )

    J_map = compute_J_map(J0_map,U_map,Uth,mask)

    Rs_map = compute_Rs_map(Vi_high,U_map,J_map,mask)

    Rs_values = Rs_map[mask & np.isfinite(Rs_map)]

    if Rs_values.size == 0:
        continue

    Rs_mean   = np.mean(Rs_values)
    Rs_median = np.median(Rs_values)

    Rs_mode = stats.mode(np.round(Rs_values,6),keepdims=False)[0]

    results.append({
        "cell": cell_id,
        "Rs_mean": Rs_mean,
        "Rs_median": Rs_median,
        "Rs_mode": Rs_mode
    })


df = pd.DataFrame(results)

print(df)

print("\nMODULE STATISTICS")
print("Mean Rs module :",df["Rs_mean"].mean())
print("Median Rs module :",df["Rs_median"].median())
# Out:
# processing cell_000
# processing cell_001
# processing cell_002
# processing cell_003
# processing cell_004
# processing cell_005
# processing cell_006
# processing cell_007
# processing cell_008
# processing cell_009
# processing cell_010
# processing cell_011
# processing cell_012
# processing cell_013
# processing cell_014
# processing cell_015
# processing cell_016
# processing cell_017
# processing cell_018
# processing cell_019
# processing cell_020
# processing cell_021
# processing cell_022
# processing cell_023
# processing cell_024
# processing cell_025
# processing cell_026
# processing cell_027
# processing cell_028
# processing cell_029
# processing cell_030
# processing cell_031
# processing cell_032
# processing cell_033
# processing cell_034
# processing cell_035
# processing cell_036
# processing cell_037
# processing cell_038
# processing cell_039
# processing cell_040
# processing cell_041
# processing cell_042
# processing cell_043
# processing cell_044
# processing cell_045
# processing cell_046
# processing cell_047
# processing cell_048
# processing cell_049
# processing cell_050
# processing cell_051
# processing cell_052
# processing cell_053
# processing cell_054
# processing cell_055
# processing cell_056
# processing cell_057
# processing cell_058
# processing cell_059
#         cell      Rs_mean    Rs_median      Rs_mode
# 0   cell_000  3781.136946  3701.994074  5050.390719
# 1   cell_001  3288.875396  3231.233604  3984.675254
# 2   cell_002  3779.842675  3692.516562  4991.668791
# 3   cell_003  3874.636768  3706.044604  5060.292628
# 4   cell_004  4137.362849  3936.249593  5528.252763
# 5   cell_005  3743.010363  3592.841973  4844.648211
# 6   cell_006  3799.469520  3648.648961  4818.302900
# 7   cell_007  3925.600950  3642.794982  5050.436954
# 8   cell_008  3725.309208  3668.608382  5103.665831
# 9   cell_009  3860.511993  3789.555925  5186.049745
# 10  cell_010  4127.450302  3965.902098  5067.347286
# 11  cell_011  4971.106115  4586.149496  6568.068879
# 12  cell_012  5201.898370  4772.077521  5899.790286
# 13  cell_013  4459.332171  4098.605517  5470.618535
# 14  cell_014  4492.958835  4175.354219  5344.223285
# 15  cell_015  4366.659620  4098.286094  5487.262521
# 16  cell_016  4498.444570  4161.433009  5704.805675
# 17  cell_017  4498.180808  4164.602366  5177.114398
# 18  cell_018  4586.334442  4260.253375  5476.885377
# 19  cell_019  3374.892221  3196.875507  4332.726171
# 20  cell_020  3734.546334  3645.468191  4751.139125
# 21  cell_021  4097.045668  3971.837726  5453.819543
# 22  cell_022  4071.736609  3961.939222  5029.306591
# 23  cell_023  4004.382742  3878.433607  4928.695318
# 24  cell_024  4320.577573  4165.765498  5379.144249
# 25  cell_025  4803.097371  4190.999636  4417.740646
# 26  cell_026  4253.697072  4090.465152  5657.404379
# 27  cell_027  4066.682949  3883.060328  5338.612170
# 28  cell_028  4098.803290  3907.288237  5290.216314
# 29  cell_029  4111.687626  3950.257725  5451.406606
# 30  cell_030  4298.966963  4148.048597  5907.772778
# 31  cell_031  4209.037951  4076.382066  5042.886496
# 32  cell_032  4363.083383  4191.612220  5254.436237
# 33  cell_033  4144.880251  3934.347426  5396.605165
# 34  cell_034  4440.751877  4277.994682  5401.228332
# 35  cell_035  4309.541918  4136.005212  5023.575269
# 36  cell_036  4457.506683  4286.204659  5272.698728
# 37  cell_037  4282.481598  4149.784251  5550.117335
# 38  cell_038  4490.140424  4326.648328  4846.636307
# 39  cell_039  3674.325574  3583.021721  4905.264278
# 40  cell_040  3833.147262  3687.695281  4659.650192
# 41  cell_041  4099.633428  3933.951486  5103.612375
# 42  cell_042  4078.125635  3890.472645  4585.084690
# 43  cell_043  4029.578116  3869.183805  4789.456394
# 44  cell_044  4070.398086  3889.358411  4868.898997
# 45  cell_045  4189.782633  4026.959850  4261.837075
# 46  cell_046  3977.842090  3746.757719  4060.909558
# 47  cell_047  3975.760379  3850.518152  4789.083547
# 48  cell_048  3833.308869  3664.848986  4820.029251
# 49  cell_049  4180.901859  3986.447213  5385.205074
# 50  cell_050  4504.337834  4367.014441  4597.941835
# 51  cell_051  4236.064337  4109.399139  4965.346588
# 52  cell_052  4469.965620  4333.814935  6376.900433
# 53  cell_053  4575.044517  4420.180621  5650.157460
# 54  cell_054  4837.288687  4619.772848  5859.509450
# 55  cell_055  5603.042844  5203.952775  6012.024915
# 56  cell_056  5552.846172  5302.045976  5809.190432
# 57  cell_057  5349.259855  5101.842901  6999.518383
# 58  cell_058  5589.082512  5310.273582  7854.636502
# 59  cell_059  3614.694619  3480.817106  5179.695320
#
# MODULE STATISTICS
# Mean Rs module : 4255.434888826246
# Median Rs module : 3979.1424695440655

# %% [markdown]
# # Run Per Cell NEW

# %%
import os
import glob
import re
import numpy as np
import pandas as pd
from scipy import stats


def estimate_rs_per_cell(
    low_folder: str,
    high_folder: str,
    I_low,
    Uth,
    VT,
    N,
    pattern: str = "*.tif*"
):
    """
    Hitung Rs per cell dengan memasangkan file low-bias dan high-bias
    berdasarkan cell_id (mis. cell_000, cell_001, dst).

    Return:
        dict berisi hasil per cell dan statistik modul
    """

    low_files = sorted(glob.glob(os.path.join(low_folder, pattern)))
    high_files = sorted(glob.glob(os.path.join(high_folder, pattern)))

    if not low_files:
        raise FileNotFoundError(f"Tidak ada file low-bias di folder: {low_folder}")
    if not high_files:
        raise FileNotFoundError(f"Tidak ada file high-bias di folder: {high_folder}")

    # --------------------------------
    # index high files by cell id
    # --------------------------------
    high_dict = {}
    for fpath in high_files:
        name = os.path.basename(fpath)
        m = re.search(r'wrp_\d+', name)
        if m is not None:
            cell_id = m.group()
            high_dict[cell_id] = fpath

    results = []
    missing_pairs = []

    for low_path in low_files:
        low_name = os.path.basename(low_path)

        m = re.search(r'wrp_\d+', low_name)
        if m is None:
            print(f"Skip file low tanpa cell_id: {low_name}")
            continue

        cell_id = m.group()

        if cell_id not in high_dict:
            missing_pairs.append(cell_id)
            continue

        high_path = high_dict[cell_id]

        # ---------------------
        # LOW BIAS
        # ---------------------
        phi_low_img = load_gray_cv2(low_path)

        phi_low_values = load_image_and_remove_padding(low_path)
        phi_low_values = trim_outliers(phi_low_values, 0.1, 99.9)

        f = compute_f(phi_low_values, I=I_low, Uth=Uth, VT=VT, N=N)

        Vi_low = compute_Vi_from_phi_values(
            phi_low_values,
            I=I_low,
            f=f,
            Uth=Uth
        )

        c_map, mask_low = compute_c_map(phi_low_img, Vi_low, Uth=Uth)
        J0_map = compute_J0_map(c_map, f)

        # ---------------------
        # HIGH BIAS
        # ---------------------
        phi_high_img = load_gray_cv2(high_path)
        mask_high = make_valid_mask(phi_high_img)

        mask = mask_low & mask_high

        U_map = compute_U_map(
            phi_high_img,
            c_map=c_map,
            Uth=Uth,
            mask=mask
        )

        Vi_high = estimate_Vi_from_brightest(
            phi_high_img,
            U_map=U_map,
            mask=mask,
            exclude_top_percent=0.1
        )

        J_map = compute_J_map(J0_map, U_map, Uth, mask)
        Rs_map = compute_Rs_map(Vi_high, U_map, J_map, mask)

        Rs_values = Rs_map[mask & np.isfinite(Rs_map)]

        if Rs_values.size == 0:
            results.append({
                "cell": cell_id,
                "low_file": low_name,
                "high_file": os.path.basename(high_path),
                "Rs_mean": np.nan,
                "Rs_median": np.nan,
                "Rs_mode": np.nan,
                "n_valid_pixels": 0
            })
            continue

        Rs_mean = float(np.mean(Rs_values))
        Rs_median = float(np.median(Rs_values))
        Rs_mode = float(stats.mode(np.round(Rs_values, 6), keepdims=False)[0])

        results.append({
            "cell": cell_id,
            "low_file": low_name,
            "high_file": os.path.basename(high_path),
            "Rs_mean": Rs_mean,
            "Rs_median": Rs_median,
            "Rs_mode": Rs_mode,
            "n_valid_pixels": int(Rs_values.size)
        })

    df = pd.DataFrame(results)

    return {
        "df": df,
        "missing_pairs": missing_pairs,
        "n_low_files": len(low_files),
        "n_high_files": len(high_files)
    }


def print_rs_summary_for_module(
    low_folder: str,
    high_folder: str,
    I_low,
    Uth,
    VT,
    N,
    pattern: str = "*.tiff*"
):
    """
    Jalankan perhitungan Rs untuk satu modul/folder lalu print:
    - hasil Rs per cell
    - statistik modul
    """

    out = estimate_rs_per_cell(
        low_folder=low_folder,
        high_folder=high_folder,
        I_low=I_low,
        Uth=Uth,
        VT=VT,
        N=N,
        pattern=pattern
    )

    df = out["df"]
    missing_pairs = out["missing_pairs"]

    print("=" * 100)
    print("LOW FOLDER  :", low_folder)
    print("HIGH FOLDER :", high_folder)
    print("Jumlah low files  :", out["n_low_files"])
    print("Jumlah high files :", out["n_high_files"])
    print("=" * 100)

    if missing_pairs:
        print("\nPAIR YANG HILANG")
        print("-" * 100)
        for cid in missing_pairs:
            print("missing pair:", cid)

    print("\nHASIL Rs PER CELL")
    print("-" * 100)

    if df.empty:
        print("Tidak ada hasil yang berhasil dihitung.")
        return out

    for _, row in df.iterrows():
        print(
            f"{row['cell']:10s} | "
            f"Rs_mean = {row['Rs_mean']:12.6f} | "
            f"Rs_median = {row['Rs_median']:12.6f} | "
            f"Rs_mode = {row['Rs_mode']:12.6f} | "
            f"n_valid_pixels = {int(row['n_valid_pixels'])}"
        )

    valid_mean = df["Rs_mean"].dropna()
    valid_median = df["Rs_median"].dropna()
    valid_mode = df["Rs_mode"].dropna()

    print("\n" + "=" * 100)
    print("RINGKASAN MODUL")
    print("-" * 100)
    print("Jumlah cell diproses :", len(df))
    print("Jumlah cell valid    :", int(df["Rs_mean"].notna().sum()))

    if len(valid_mean) > 0:
        print("Mean Rs module       :", float(valid_mean.mean()))
        print("Median dari Rs_mean  :", float(valid_mean.median()))
        print("Min Rs_mean          :", float(valid_mean.min()))
        print("Max Rs_mean          :", float(valid_mean.max()))

    if len(valid_median) > 0:
        print("Median Rs module     :", float(valid_median.median()))

    if len(valid_mode) > 0:
        mode_module = float(stats.mode(np.round(valid_mode.values, 6), keepdims=False)[0])
        print("Mode Rs module       :", mode_module)

    print("=" * 100)

    return out

# %%
if __name__ == "__main__":
    low_folder  = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_20_wrp"
    high_folder = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_80_wrp"

    # isi sesuai parameter kamu
    I_low = 1.922
    Uth = 0.026
    VT = 0.0
    N = 60

    out = print_rs_summary_for_module(
        low_folder=low_folder,
        high_folder=high_folder,
        I_low=I_low,
        Uth=Uth,
        VT=VT,
        N=N
    )

    # kalau mau dataframe-nya juga
    df_rs = out["df"]
# Out:
# ====================================================================================================
# LOW FOLDER  : C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_20_wrp
# HIGH FOLDER : C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_80_wrp
# Jumlah low files  : 60
# Jumlah high files : 60
# ====================================================================================================
#
# HASIL Rs PER CELL
# ----------------------------------------------------------------------------------------------------
# wrp_000    | Rs_mean =   413.171872 | Rs_median =   425.416479 | Rs_mode =   546.563047 | n_valid_pixels = 282444
# wrp_001    | Rs_mean =   355.335814 | Rs_median =   358.598428 | Rs_mode =   517.190189 | n_valid_pixels = 285357
# wrp_002    | Rs_mean =   381.686371 | Rs_median =   393.360496 | Rs_mode =   475.331374 | n_valid_pixels = 285794
# wrp_003    | Rs_mean =   422.041546 | Rs_median =   434.866583 | Rs_mode =   539.814642 | n_valid_pixels = 285226
# wrp_004    | Rs_mean =   367.080240 | Rs_median =   371.999489 | Rs_mode =   392.613726 | n_valid_pixels = 284715
# wrp_005    | Rs_mean =   437.941755 | Rs_median =   446.008514 | Rs_mode =   523.215968 | n_valid_pixels = 284953
# wrp_006    | Rs_mean =   406.636279 | Rs_median =   418.298503 | Rs_mode =   515.332809 | n_valid_pixels = 285125
# wrp_007    | Rs_mean =   391.415917 | Rs_median =   402.078248 | Rs_mode =   403.719879 | n_valid_pixels = 285039
# wrp_008    | Rs_mean =   384.528833 | Rs_median =   396.463590 | Rs_mode =   429.378864 | n_valid_pixels = 285247
# wrp_009    | Rs_mean =   324.347249 | Rs_median =   341.099934 | Rs_mode =     0.000000 | n_valid_pixels = 276850
# wrp_010    | Rs_mean =   418.704071 | Rs_median =   438.489384 | Rs_mode =   548.782217 | n_valid_pixels = 287315
# wrp_011    | Rs_mean =   430.650914 | Rs_median =   444.455541 | Rs_mode =   505.176163 | n_valid_pixels = 289908
# wrp_012    | Rs_mean =   499.844822 | Rs_median =   511.156484 | Rs_mode =     0.000000 | n_valid_pixels = 292626
# wrp_013    | Rs_mean =   529.619841 | Rs_median =   541.747743 | Rs_mode =   670.007724 | n_valid_pixels = 292203
# wrp_014    | Rs_mean =   432.076313 | Rs_median =   445.653778 | Rs_mode =   503.022702 | n_valid_pixels = 292438
# wrp_015    | Rs_mean =   466.987189 | Rs_median =   480.098855 | Rs_mode =   520.414651 | n_valid_pixels = 292733
# wrp_016    | Rs_mean =   481.153579 | Rs_median =   497.577020 | Rs_mode =   565.900687 | n_valid_pixels = 291496
# wrp_017    | Rs_mean =   462.026656 | Rs_median =   471.159650 | Rs_mode =   555.208376 | n_valid_pixels = 289973
# wrp_018    | Rs_mean =   448.526820 | Rs_median =   458.210405 | Rs_mode =   619.161657 | n_valid_pixels = 285409
# wrp_019    | Rs_mean =   475.558778 | Rs_median =   487.073655 | Rs_mode =   584.777957 | n_valid_pixels = 276830
# wrp_020    | Rs_mean =   443.795018 | Rs_median =   462.026632 | Rs_mode =   588.342921 | n_valid_pixels = 286125
# wrp_021    | Rs_mean =   469.629774 | Rs_median =   487.325342 | Rs_mode =   572.230388 | n_valid_pixels = 291094
# wrp_022    | Rs_mean =   528.438727 | Rs_median =   529.259289 | Rs_mode =   639.815734 | n_valid_pixels = 293122
# wrp_023    | Rs_mean =   474.014754 | Rs_median =   484.631444 | Rs_mode =   503.955705 | n_valid_pixels = 294624
# wrp_024    | Rs_mean =   486.756945 | Rs_median =   505.243924 | Rs_mode =   554.298977 | n_valid_pixels = 295224
# wrp_025    | Rs_mean =   467.264742 | Rs_median =   486.209601 | Rs_mode =   570.531361 | n_valid_pixels = 295036
# wrp_026    | Rs_mean =   498.687335 | Rs_median =   519.764358 | Rs_mode =   623.717230 | n_valid_pixels = 294317
# wrp_027    | Rs_mean =   526.156854 | Rs_median =   544.036453 | Rs_mode =   624.173904 | n_valid_pixels = 292136
# wrp_028    | Rs_mean =   455.342236 | Rs_median =   467.953533 | Rs_mode =   487.968698 | n_valid_pixels = 289342
# wrp_029    | Rs_mean =   427.305663 | Rs_median =   437.885927 | Rs_mode =   494.594601 | n_valid_pixels = 279986
# wrp_030    | Rs_mean =   536.807317 | Rs_median =   542.304538 | Rs_mode =   618.161216 | n_valid_pixels = 283542
# wrp_031    | Rs_mean =   495.266847 | Rs_median =   495.595434 | Rs_mode =   540.819264 | n_valid_pixels = 291375
# wrp_032    | Rs_mean =   495.788372 | Rs_median =   512.616083 | Rs_mode =   578.678885 | n_valid_pixels = 293792
# wrp_033    | Rs_mean =   491.526623 | Rs_median =   505.456614 | Rs_mode =   635.490592 | n_valid_pixels = 295911
# wrp_034    | Rs_mean =   478.409304 | Rs_median =   490.169909 | Rs_mode =   516.804234 | n_valid_pixels = 296492
# wrp_035    | Rs_mean =   467.904570 | Rs_median =   475.402317 | Rs_mode =   483.636735 | n_valid_pixels = 294989
# wrp_036    | Rs_mean =   517.780373 | Rs_median =   530.434419 | Rs_mode =   606.422178 | n_valid_pixels = 294336
# wrp_037    | Rs_mean =   503.238786 | Rs_median =   514.485404 | Rs_mode =   596.403314 | n_valid_pixels = 290768
# wrp_038    | Rs_mean =   525.044552 | Rs_median =   534.000123 | Rs_mode =   660.596344 | n_valid_pixels = 288579
# wrp_039    | Rs_mean =   415.053216 | Rs_median =   424.148308 | Rs_mode =   489.981312 | n_valid_pixels = 279863
# wrp_040    | Rs_mean =   404.235707 | Rs_median =   412.411650 | Rs_mode =   475.140072 | n_valid_pixels = 283898
# wrp_041    | Rs_mean =   476.859052 | Rs_median =   488.030629 | Rs_mode =    -0.000000 | n_valid_pixels = 291456
# wrp_042    | Rs_mean =   481.704741 | Rs_median =   497.991281 | Rs_mode =   549.242074 | n_valid_pixels = 293196
# wrp_043    | Rs_mean =   490.279745 | Rs_median =   499.996187 | Rs_mode =   526.359091 | n_valid_pixels = 294171
# wrp_044    | Rs_mean =   435.439687 | Rs_median =   439.208831 | Rs_mode =   516.654295 | n_valid_pixels = 294367
# wrp_045    | Rs_mean =   506.878063 | Rs_median =   522.239946 | Rs_mode =   569.648662 | n_valid_pixels = 295313
# wrp_046    | Rs_mean =   496.736322 | Rs_median =   516.393666 | Rs_mode =   570.578175 | n_valid_pixels = 292777
# wrp_047    | Rs_mean =   529.715360 | Rs_median =   546.717494 | Rs_mode =   608.503591 | n_valid_pixels = 290756
# wrp_048    | Rs_mean =   418.270301 | Rs_median =   435.041812 | Rs_mode =   579.719191 | n_valid_pixels = 287862
# wrp_049    | Rs_mean =   438.130060 | Rs_median =   457.423139 | Rs_mode =   571.675088 | n_valid_pixels = 282211
# wrp_050    | Rs_mean =   415.798344 | Rs_median =   428.998509 | Rs_mode =   512.035690 | n_valid_pixels = 279828
# wrp_051    | Rs_mean =   386.919511 | Rs_median =   402.119374 | Rs_mode =   512.254160 | n_valid_pixels = 286237
# wrp_052    | Rs_mean =   414.860738 | Rs_median =   428.904962 | Rs_mode =   560.020069 | n_valid_pixels = 285635
# wrp_053    | Rs_mean =   438.705829 | Rs_median =   450.193495 | Rs_mode =   562.852955 | n_valid_pixels = 286033
# wrp_054    | Rs_mean =   412.225172 | Rs_median =   420.821087 | Rs_mode =   517.183737 | n_valid_pixels = 285934
# wrp_055    | Rs_mean =   399.849533 | Rs_median =   410.995703 | Rs_mode =   525.043007 | n_valid_pixels = 286152
# wrp_056    | Rs_mean =   414.967167 | Rs_median =   422.728654 | Rs_mode =   544.500059 | n_valid_pixels = 286704
# wrp_057    | Rs_mean =   431.872767 | Rs_median =   447.808287 | Rs_mode =   581.321366 | n_valid_pixels = 286804
# wrp_058    | Rs_mean =   458.955473 | Rs_median =   472.733853 | Rs_mode =   553.897893 | n_valid_pixels = 286205
# wrp_059    | Rs_mean =   347.214338 | Rs_median =   352.595320 | Rs_mode =   477.708343 | n_valid_pixels = 281624
#
# ====================================================================================================
# RINGKASAN MODUL
# ----------------------------------------------------------------------------------------------------
# Jumlah cell diproses : 60
# Jumlah cell valid    : 60
# Mean Rs module       : 450.55274626631007
# Median dari Rs_mean  : 451.9345279680906
# Min Rs_mean          : 324.3472489188427
# Max Rs_mean          : 536.8073174522227
# Median Rs module     : 464.9900824693292
# Mode Rs module       : -0.0
# ====================================================================================================

# %% [markdown]
# # Rp estimation => Timo Kropp, 2018

# %%
import os
import glob
import cv2
import numpy as np



def load_gray_tiff_cv2(path: str) -> np.ndarray:
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Gagal load image: {path}")
    return img.astype(np.float32)


def mean_intensity_excluding_padding(img: np.ndarray, min_valid: int = 2) -> float:
    """
    Hitung mean intensity dengan buang pixel 0-1 (padding/bezel).
    """
    m = img >= float(min_valid)
    if np.sum(m) == 0:
        return float("nan")
    return float(np.mean(img[m]))


def compute_CPRA(phi_ref: float, J0: float, nid: float, Vth: float, rref_p: float) -> float:
    """
    Eq (9) paper: CPRA dihitung dari sel referensi pakai Lambert-W (main branch W0).
    CPRA = (J0 rref_p Phi_ref)/(nid Vth) * [ W0( (J0 rref_p)/(nid Vth) * exp(J0 rref_p/(nid Vth)) ) ]^{-1}
    """
    a = (J0 * rref_p) / (nid * Vth)  # dimensionless
    W = lambertw(a * np.exp(a), k=0)  # main branch
    W = np.real(W)
    if W <= 0:
        raise ValueError("LambertW menghasilkan nilai non-positif. Cek parameter J0, nid, rref_p.")
    CPRA = (J0 * rref_p * phi_ref) / (nid * Vth * W)
    return float(CPRA)


def rp_from_mean_intensity(phi_i: float, CPRA: float, Jc: float, J0: float, nid: float, Vth: float) -> float:
    """
    Eq (10) paper:
    r_i,p = (nid Vth ln(phi_i/CPRA)) / (Jc - J0 * (phi_i/CPRA))
    """
    if not np.isfinite(phi_i) or phi_i <= 0:
        return float("nan")

    x = phi_i / CPRA
    if x <= 0:
        return float("nan")

    num = nid * Vth * np.log(x)
    den = Jc - J0 * x

    # Untuk kasus shunt kuat, den bisa mendekati 0 atau negatif -> tidak fisik untuk PRA
    if den <= 0:
        return float("nan")

    rp = num / den
    # rp harus positif (Ω·cm²). Jika negatif -> parameter/assumption tidak cocok.
    if rp <= 0:
        return float("nan")

    return float(rp)


def estimate_rparallel_per_cell(
    folder_low_cells: str,
    Jc: float,                 # A/cm^2
    J0: float,                 # A/cm^2
    nid: float = 1.2,
    Vth: float = 0.0259,       # kT/q at ~300K (tanpa n). Di rumus pakai nid*Vth, jadi Vth di sini adalah (kT/q).
    rref_p: float = 1e6,       # Ω·cm^2 (sel referensi "baik" -> besar)
    min_valid_intensity: int = 2,
    pattern: str = "*_cell_*.tif*"
):
    """
    Menghasilkan array:
    cell_name, mean_intensity, rp (Ω·cm²)

    Asumsi sesuai PRA:
    - Low current: Rs & Rcon diabaikan (Jc < ~10% Jsc) :contentReference[oaicite:2]{index=2}
    - Defect dominan mengubah Rp, bukan Rs
    - J0 & nid sama untuk semua cell
    """
    paths = sorted(glob.glob(os.path.join(folder_low_cells, pattern)))
    if not paths:
        raise FileNotFoundError(f"Tidak ada file cocok pattern {pattern} di {folder_low_cells}")

    # 1) mean intensity per cell
    cell_names = []
    phi_means = []
    for p in paths:
        img = load_gray_tiff_cv2(p)
        phi = mean_intensity_excluding_padding(img, min_valid=min_valid_intensity)
        cell_names.append(os.path.basename(p))
        phi_means.append(phi)

    phi_means = np.array(phi_means, dtype=np.float64)

    # 2) pilih reference cell: mean intensity tertinggi (best cell)
    idx_ref = int(np.nanargmax(phi_means))
    phi_ref = float(phi_means[idx_ref])

    # 3) hitung CPRA dari Eq (9)
    CPRA = compute_CPRA(phi_ref=phi_ref, J0=J0, nid=nid, Vth=Vth, rref_p=rref_p)

    # 4) hitung rp tiap cell (Eq 10)
    rps = []
    for phi in phi_means:
        rp = rp_from_mean_intensity(phi_i=float(phi), CPRA=CPRA, Jc=Jc, J0=J0, nid=nid, Vth=Vth)
        rps.append(rp)

    rps = np.array(rps, dtype=np.float64)

    result = {
        "cell_names": cell_names,
        "phi_mean": phi_means,
        "rp_ohm_cm2": rps,
        "ref_cell": cell_names[idx_ref],
        "phi_ref": phi_ref,
        "CPRA": CPRA
    }
    return result


# -------------------------
# CONTOH PAKAI
# -------------------------
if __name__ == "__main__":
    folder_low = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\10084_35_1_01272020_20"

    # Kamu isi ini dari arus injeksi / area cell:
    # contoh: I = 0.6 A, area cell = 243 cm^2 => Jc = 0.00247 A/cm^2
    Jc = 0.0025

    # Parameter model (kalau belum ada, isi dulu untuk uji pipeline):
    nid = 1.2
    Vth = 0.0259
    J0 = 1e-9
    rref_p = 1e6

    out = estimate_rparallel_per_cell(
        folder_low_cells=folder_low,
        Jc=Jc,
        J0=J0,
        nid=nid,
        Vth=Vth,
        rref_p=rref_p
    )

    print("Reference cell:", out["ref_cell"])
    print("CPRA:", out["CPRA"])
    # Tampilkan 5 pertama
    for n, phi, rp in list(zip(out["cell_names"], out["phi_mean"], out["rp_ohm_cm2"]))[:5]:
        print(n, "phi_mean=", phi, "rp(ohm*cm2)=", rp)

# %% [markdown]
# # Rp estimation => Timo Kropp, 2018 Per Cell

# %%
import os
import glob
import cv2
import numpy as np
from scipy.special import lambertw


def load_gray_tiff_cv2(path: str) -> np.ndarray:
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Gagal load image: {path}")
    return img.astype(np.float32)


def mean_intensity_excluding_padding(img: np.ndarray, min_valid: int = 2) -> float:
    """
    Hitung mean intensity dengan buang pixel 0-1 (padding/bezel).
    """
    m = img >= float(min_valid)
    if np.sum(m) == 0:
        return float("nan")
    return float(np.mean(img[m]))


def compute_CPRA(phi_ref: float, J0: float, nid: float, Vth: float, rref_p: float) -> float:
    """
    Hitung CPRA berdasarkan reference cell.
    """
    a = (J0 * rref_p) / (nid * Vth)
    W = lambertw(a * np.exp(a), k=0)
    W = np.real(W)

    if W <= 0:
        raise ValueError("LambertW menghasilkan nilai non-positif. Cek parameter J0, nid, rref_p.")

    CPRA = (J0 * rref_p * phi_ref) / (nid * Vth * W)
    return float(CPRA)


def rp_from_mean_intensity(phi_i: float, CPRA: float, Jc: float, J0: float, nid: float, Vth: float) -> float:
    """
    Hitung Rp dari mean intensity.
    """
    if not np.isfinite(phi_i) or phi_i <= 0:
        return float("nan")

    x = phi_i / CPRA
    if x <= 0:
        return float("nan")

    num = nid * Vth * np.log(x)
    den = Jc - J0 * x

    if den <= 0:
        return float("nan")

    rp = num / den
    if rp <= 0:
        return float("nan")

    return float(rp)


def estimate_rparallel_per_cell(
    folder_low_cells: str,
    Jc: float,
    J0: float,
    nid: float = 1.2,
    Vth: float = 0.0259,
    rref_p: float = 1e6,
    min_valid_intensity: int = 2,
    pattern: str = "*_cell_*.tif*"
):
    """
    Menghasilkan Rp tiap cell dalam satu folder.
    """
    paths = sorted(glob.glob(os.path.join(folder_low_cells, pattern)))
    if not paths:
        raise FileNotFoundError(f"Tidak ada file cocok pattern {pattern} di {folder_low_cells}")

    cell_names = []
    phi_means = []

    for p in paths:
        img = load_gray_tiff_cv2(p)
        phi = mean_intensity_excluding_padding(img, min_valid=min_valid_intensity)
        cell_names.append(os.path.basename(p))
        phi_means.append(phi)

    phi_means = np.array(phi_means, dtype=np.float64)

    idx_ref = int(np.nanargmax(phi_means))
    phi_ref = float(phi_means[idx_ref])
    ref_cell = cell_names[idx_ref]

    CPRA = compute_CPRA(phi_ref=phi_ref, J0=J0, nid=nid, Vth=Vth, rref_p=rref_p)

    rps = []
    for phi in phi_means:
        rp = rp_from_mean_intensity(
            phi_i=float(phi),
            CPRA=CPRA,
            Jc=Jc,
            J0=J0,
            nid=nid,
            Vth=Vth
        )
        rps.append(rp)

    rps = np.array(rps, dtype=np.float64)

    return {
        "cell_names": cell_names,
        "phi_mean": phi_means,
        "rp_ohm_cm2": rps,
        "ref_cell": ref_cell,
        "phi_ref": phi_ref,
        "CPRA": CPRA
    }


def print_rp_summary_for_folder(
    folder_low_cells: str,
    Jc: float,
    J0: float,
    nid: float = 1.2,
    Vth: float = 0.0259,
    rref_p: float = 1e6,
    min_valid_intensity: int = 2,
    pattern: str = "*_wrp_*.tiff*"
):
    """
    Jalankan perhitungan Rp untuk satu folder lalu print hasil tiap cell
    dan summary folder.
    """
    out = estimate_rparallel_per_cell(
        folder_low_cells=folder_low_cells,
        Jc=Jc,
        J0=J0,
        nid=nid,
        Vth=Vth,
        rref_p=rref_p,
        min_valid_intensity=min_valid_intensity,
        pattern=pattern
    )

    print("=" * 80)
    print("FOLDER :", folder_low_cells)
    print("Reference cell :", out["ref_cell"])
    print("Phi ref        :", out["phi_ref"])
    print("CPRA           :", out["CPRA"])
    print("=" * 80)
    print()

    print("HASIL Rp PER CELL")
    print("-" * 80)
    for name, phi, rp in zip(out["cell_names"], out["phi_mean"], out["rp_ohm_cm2"]):
        print(f"{name:40s} | phi_mean = {phi:10.4f} | Rp = {rp:15.6f} ohm.cm^2")

    valid_rp = out["rp_ohm_cm2"][np.isfinite(out["rp_ohm_cm2"])]

    print()
    print("=" * 80)
    print("RINGKASAN FOLDER")
    print("-" * 80)
    print("Jumlah cell total  :", len(out["cell_names"]))
    print("Jumlah Rp valid    :", len(valid_rp))

    if len(valid_rp) > 0:
        print("Rp rata-rata       :", float(np.mean(valid_rp)), "ohm.cm^2")
        print("Rp median          :", float(np.median(valid_rp)), "ohm.cm^2")
        print("Rp minimum         :", float(np.min(valid_rp)), "ohm.cm^2")
        print("Rp maksimum        :", float(np.max(valid_rp)), "ohm.cm^2")
    else:
        print("Tidak ada Rp valid.")
    print("=" * 80)

    return out


# -------------------------------------------------------------------
# CONTOH PAKAI
# -------------------------------------------------------------------
if __name__ == "__main__":
    folder_low = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_20_wrp"

    # Contoh parameter
    Jc = 0.0025
    J0 = 1e-9
    nid = 1.2
    Vth = 0.0259
    rref_p = 1e6

    print_rp_summary_for_folder(
        folder_low_cells=folder_low,
        Jc=Jc,
        J0=J0,
        nid=nid,
        Vth=Vth,
        rref_p=rref_p
    )
# Out:
# ================================================================================
# FOLDER : C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\3922_20_1_01232020_20_wrp
# Reference cell : 3922_20_1_01232020_20_wrp_056.tiff
# Phi ref        : 124.22268676757812
# CPRA           : 124.22268676757812
# ================================================================================
#
# HASIL Rp PER CELL
# --------------------------------------------------------------------------------
# 3922_20_1_01232020_20_wrp_000.tiff       | phi_mean =    88.6308 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_001.tiff       | phi_mean =    87.7471 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_002.tiff       | phi_mean =    73.8633 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_003.tiff       | phi_mean =    71.2959 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_004.tiff       | phi_mean =    80.2942 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_005.tiff       | phi_mean =    76.9498 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_006.tiff       | phi_mean =    75.9900 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_007.tiff       | phi_mean =    69.5601 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_008.tiff       | phi_mean =    83.3662 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_009.tiff       | phi_mean =    98.1410 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_010.tiff       | phi_mean =   103.4192 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_011.tiff       | phi_mean =    95.3577 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_012.tiff       | phi_mean =   101.7070 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_013.tiff       | phi_mean =    67.5443 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_014.tiff       | phi_mean =   104.3459 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_015.tiff       | phi_mean =   120.4874 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_016.tiff       | phi_mean =   107.7477 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_017.tiff       | phi_mean =   109.2590 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_018.tiff       | phi_mean =    71.3379 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_019.tiff       | phi_mean =   102.0769 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_020.tiff       | phi_mean =   102.1228 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_021.tiff       | phi_mean =    77.5451 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_022.tiff       | phi_mean =    78.8162 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_023.tiff       | phi_mean =    82.7012 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_024.tiff       | phi_mean =    87.8791 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_025.tiff       | phi_mean =    82.1812 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_026.tiff       | phi_mean =   101.5238 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_027.tiff       | phi_mean =   112.4379 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_028.tiff       | phi_mean =   109.2777 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_029.tiff       | phi_mean =    93.5682 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_030.tiff       | phi_mean =    79.7996 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_031.tiff       | phi_mean =    85.8440 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_032.tiff       | phi_mean =    94.7896 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_033.tiff       | phi_mean =   107.2911 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_034.tiff       | phi_mean =    99.8984 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_035.tiff       | phi_mean =    71.1835 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_036.tiff       | phi_mean =    89.5905 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_037.tiff       | phi_mean =    71.4647 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_038.tiff       | phi_mean =    84.2671 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_039.tiff       | phi_mean =    78.0053 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_040.tiff       | phi_mean =    83.1596 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_041.tiff       | phi_mean =    92.9539 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_042.tiff       | phi_mean =    82.0932 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_043.tiff       | phi_mean =    82.4861 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_044.tiff       | phi_mean =    73.3973 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_045.tiff       | phi_mean =   103.2174 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_046.tiff       | phi_mean =    79.2733 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_047.tiff       | phi_mean =    78.7810 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_048.tiff       | phi_mean =    79.4204 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_049.tiff       | phi_mean =    84.2700 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_050.tiff       | phi_mean =   101.9113 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_051.tiff       | phi_mean =   110.6277 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_052.tiff       | phi_mean =    78.2248 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_053.tiff       | phi_mean =    78.0854 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_054.tiff       | phi_mean =    98.9146 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_055.tiff       | phi_mean =    87.8536 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_056.tiff       | phi_mean =   124.2227 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_057.tiff       | phi_mean =   113.5196 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_058.tiff       | phi_mean =   112.2126 | Rp =             nan ohm.cm^2
# 3922_20_1_01232020_20_wrp_059.tiff       | phi_mean =   123.7479 | Rp =             nan ohm.cm^2
#
# ================================================================================
# RINGKASAN FOLDER
# --------------------------------------------------------------------------------
# Jumlah cell total  : 60
# Jumlah Rp valid    : 0
# Tidak ada Rp valid.
# ================================================================================

# %%
def load_gray_tiff(path: str) -> np.ndarray:
    """
    Load 8-bit grayscale TIFF using OpenCV
    """
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Gagal load image: {path}")
    return img.astype(np.float32)


def mask_valid(*imgs, min_valid=2):
    mask = np.ones_like(imgs[0], dtype=bool)
    for im in imgs:
        mask &= (im >= float(min_valid))
    return mask


def estimate_uter(deltaU, phi_high, mask, exclude_top_percent=0.1):
    """
    Estimate (Uter - Ulow) from brightest region
    excluding top 0.1% intensities
    """
    safe = mask & np.isfinite(deltaU)
    vals = phi_high[safe]

    p_hi = 100.0 - exclude_top_percent
    p_lo = p_hi - 0.4

    thr_hi = np.percentile(vals, p_hi)
    thr_lo = np.percentile(vals, p_lo)

    band = safe & (phi_high >= thr_lo) & (phi_high <= thr_hi)

    if np.sum(band) == 0:
        return float(np.nanmax(deltaU[safe]))

    return float(np.nanmedian(deltaU[band]))


def rs_from_ratio_cv2(phi_low_path,
                      phi_high_path,
                      Uth,
                      J_inj,
                      min_valid=2,
                      exclude_top_percent=0.1):

    phi_low  = load_gray_tiff(phi_low_path)
    phi_high = load_gray_tiff(phi_high_path)

    mask = mask_valid(phi_low, phi_high, min_valid=min_valid) \
           & (phi_low > 0) & (phi_high > 0)

    deltaU = np.full_like(phi_low, np.nan, dtype=np.float32)
    deltaU[mask] = Uth * np.log(phi_high[mask] / phi_low[mask])

    Uter_minus_Ulow = estimate_uter(deltaU, phi_high, mask, exclude_top_percent)

    Rs = np.full_like(deltaU, np.nan, dtype=np.float32)
    Rs[mask] = (Uter_minus_Ulow - deltaU[mask]) / float(J_inj)

    # c(r) relatif
    c_rel = np.full_like(phi_low, np.nan, dtype=np.float32)
    c_rel[mask] = phi_low[mask] / np.nanmedian(phi_low[mask])

    return {
        "Rs_map": Rs,
        "deltaU": deltaU,
        "Uter_minus_Ulow": Uter_minus_Ulow,
        "c_rel": c_rel
    }

# %%
result = rs_from_ratio_cv2(
    phi_low_path = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\10084_35_1_01272020_20\10084_35_1_01272020_20_cell_000.tiff",
    phi_high_path = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\10084_35_1_01272020_80\10084_35_1_01272020_80_cell_000.tiff",
    Uth=0.0259,        # bisa treat sebagai effective parameter
    J_inj=0.05         # A/cm² (I_inj / area_cell)
)

print("Median Rs:", np.nanmedian(result["Rs_map"]))
# Out:
# Median Rs: 0.15358216

# %%
import os
import glob
import cv2
import numpy as np



def load_gray_tiff_cv2(path: str) -> np.ndarray:
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Gagal load image: {path}")
    return img.astype(np.float32)


def mean_intensity_excluding_padding(img: np.ndarray, min_valid: int = 2) -> float:
    """
    Hitung mean intensity dengan buang pixel 0-1 (padding/bezel).
    """
    m = img >= float(min_valid)
    if np.sum(m) == 0:
        return float("nan")
    return float(np.mean(img[m]))


def compute_CPRA(phi_ref: float, J0: float, nid: float, Vth: float, rref_p: float) -> float:
    """
    Eq (9) paper: CPRA dihitung dari sel referensi pakai Lambert-W (main branch W0).
    CPRA = (J0 rref_p Phi_ref)/(nid Vth) * [ W0( (J0 rref_p)/(nid Vth) * exp(J0 rref_p/(nid Vth)) ) ]^{-1}
    """
    a = (J0 * rref_p) / (nid * Vth)  # dimensionless
    W = lambertw(a * np.exp(a), k=0)  # main branch
    W = np.real(W)
    if W <= 0:
        raise ValueError("LambertW menghasilkan nilai non-positif. Cek parameter J0, nid, rref_p.")
    CPRA = (J0 * rref_p * phi_ref) / (nid * Vth * W)
    return float(CPRA)


def rp_from_mean_intensity(phi_i: float, CPRA: float, Jc: float, J0: float, nid: float, Vth: float) -> float:
    """
    Eq (10) paper:
    r_i,p = (nid Vth ln(phi_i/CPRA)) / (Jc - J0 * (phi_i/CPRA))
    """
    if not np.isfinite(phi_i) or phi_i <= 0:
        return float("nan")

    x = phi_i / CPRA
    if x <= 0:
        return float("nan")

    num = nid * Vth * np.log(x)
    den = Jc - J0 * x

    # Untuk kasus shunt kuat, den bisa mendekati 0 atau negatif -> tidak fisik untuk PRA
    if den <= 0:
        return float("nan")

    rp = num / den
    # rp harus positif (Ω·cm²). Jika negatif -> parameter/assumption tidak cocok.
    if rp <= 0:
        return float("nan")

    return float(rp)


def estimate_rparallel_per_cell(
    folder_low_cells: str,
    Jc: float,                 # A/cm^2
    J0: float,                 # A/cm^2
    nid: float = 1.2,
    Vth: float = 0.0259,       # kT/q at ~300K (tanpa n). Di rumus pakai nid*Vth, jadi Vth di sini adalah (kT/q).
    rref_p: float = 1e6,       # Ω·cm^2 (sel referensi "baik" -> besar)
    min_valid_intensity: int = 2,
    pattern: str = "*_cell_*.tif*"
):
    """
    Menghasilkan array:
    cell_name, mean_intensity, rp (Ω·cm²)

    Asumsi sesuai PRA:
    - Low current: Rs & Rcon diabaikan (Jc < ~10% Jsc) :contentReference[oaicite:2]{index=2}
    - Defect dominan mengubah Rp, bukan Rs
    - J0 & nid sama untuk semua cell
    """
    paths = sorted(glob.glob(os.path.join(folder_low_cells, pattern)))
    if not paths:
        raise FileNotFoundError(f"Tidak ada file cocok pattern {pattern} di {folder_low_cells}")

    # 1) mean intensity per cell
    cell_names = []
    phi_means = []
    for p in paths:
        img = load_gray_tiff_cv2(p)
        phi = mean_intensity_excluding_padding(img, min_valid=min_valid_intensity)
        cell_names.append(os.path.basename(p))
        phi_means.append(phi)

    phi_means = np.array(phi_means, dtype=np.float64)

    # 2) pilih reference cell: mean intensity tertinggi (best cell)
    idx_ref = int(np.nanargmax(phi_means))
    phi_ref = float(phi_means[idx_ref])

    # 3) hitung CPRA dari Eq (9)
    CPRA = compute_CPRA(phi_ref=phi_ref, J0=J0, nid=nid, Vth=Vth, rref_p=rref_p)

    # 4) hitung rp tiap cell (Eq 10)
    rps = []
    for phi in phi_means:
        rp = rp_from_mean_intensity(phi_i=float(phi), CPRA=CPRA, Jc=Jc, J0=J0, nid=nid, Vth=Vth)
        rps.append(rp)

    rps = np.array(rps, dtype=np.float64)

    result = {
        "cell_names": cell_names,
        "phi_mean": phi_means,
        "rp_ohm_cm2": rps,
        "ref_cell": cell_names[idx_ref],
        "phi_ref": phi_ref,
        "CPRA": CPRA
    }
    return result


# -------------------------
# CONTOH PAKAI
# -------------------------
if __name__ == "__main__":
    folder_low = r"C:\Users\Ghozy Abror\OneDrive - Institut Teknologi Bandung\Karirku\UNSW\Thesis\Coding\EL_Cell\10084_35_1_01272020_20"

    # Kamu isi ini dari arus injeksi / area cell:
    # contoh: I = 0.6 A, area cell = 243 cm^2 => Jc = 0.00247 A/cm^2
    Jc = 0.0025

    # Parameter model (kalau belum ada, isi dulu untuk uji pipeline):
    nid = 1.2
    Vth = 0.0259
    J0 = 1e-9
    rref_p = 1e6

    out = estimate_rparallel_per_cell(
        folder_low_cells=folder_low,
        Jc=Jc,
        J0=J0,
        nid=nid,
        Vth=Vth,
        rref_p=rref_p
    )

    print("Reference cell:", out["ref_cell"])
    print("CPRA:", out["CPRA"])
    # Tampilkan 5 pertama
    for n, phi, rp in list(zip(out["cell_names"], out["phi_mean"], out["rp_ohm_cm2"]))[:5]:
        print(n, "phi_mean=", phi, "rp(ohm*cm2)=", rp)
# Out:
# Reference cell: 10084_35_1_01272020_20_cell_020.tiff
# CPRA: 112.51392364501953
# 10084_35_1_01272020_20_cell_000.tiff phi_mean= 80.94764709472656 rp(ohm*cm2)= nan
# 10084_35_1_01272020_20_cell_001.tiff phi_mean= 86.95196533203125 rp(ohm*cm2)= nan
# 10084_35_1_01272020_20_cell_002.tiff phi_mean= 89.15899658203125 rp(ohm*cm2)= nan
# 10084_35_1_01272020_20_cell_003.tiff phi_mean= 85.58997344970703 rp(ohm*cm2)= nan
# 10084_35_1_01272020_20_cell_004.tiff phi_mean= 85.47925567626953 rp(ohm*cm2)= nan

# %% [markdown]
# # Sisa sisa

# %%
def compute_c_from_phi(phi_values, Vi, Uth=0.0259):
    """
    c(r) = Phi(r) * exp( -U(r)/Uth ), dengan U(r) ≈ Vi untuk low bias.
    Input: phi_values (1D) sudah bersih (padding removed).
    Output: c_values (1D) untuk tiap pixel.
    """
    phi = np.asarray(phi_values, dtype=np.float64)
    if phi.size == 0:
        raise ValueError("phi_values kosong.")
    if np.any(phi <= 0):
        raise ValueError("phi_values mengandung nilai <= 0.")
    # exp(-Vi/Uth) adalah konstanta skalar untuk seluruh pixel
    return phi * np.exp(-float(Vi) / float(Uth))


def compute_J0_from_c(c_values, f):
    """
    J0(r) = f / c(r)
    """
    c = np.asarray(c_values, dtype=np.float64)
    if c.size == 0:
        raise ValueError("c_values kosong.")
    if np.any(c <= 0):
        raise ValueError("c_values mengandung nilai <= 0.")
    if f <= 0:
        raise ValueError("f harus > 0.")
    return float(f) / c


def compute_J0_cell_mean(J0_values):
    """
    J0,i = mean of J0(r) distribution inside a cell
    """
    J0 = np.asarray(J0_values, dtype=np.float64)
    if J0.size == 0:
        raise ValueError("J0_values kosong.")
    return float(np.nanmean(J0))
